# %% [markdown]
# # Muhammed Anu Rashik Vk ( Internship Project at Afame Technologies )

# %% [markdown]
# # Step 1: Load the Data

# %%
import pandas as pd

# Load the transaction data
train_data = pd.read_csv('/content/drive/MyDrive/data sets/CREDIT CARD FRAUD DETECTION data set/fraudTest.csv')
test_data = pd.read_csv('/content/drive/MyDrive/data sets/CREDIT CARD FRAUD DETECTION data set/fraudTrain.csv')

# %%
# Explore the data
train_data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
print(train_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  object
#  2   cc_num                 555719 non-null  int64
#  3   merchant               555719 non-null  object
#  4   category               555719 non-null  object
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  object
#  7   last                   555719 non-null  object
#  8   gender                 555719 non-null  object
#  9   street                 555719 non-null  object
#  10  city                   555719 non-null  object
#  11  state                  555719 non-null  object
#  12  zip                    555719 non-null  int64
#  13  lat                    555719 non-null  float64
# ...

# %%
print(train_data.describe())
# Out:
#           Unnamed: 0        cc_num            amt            zip  \
# count  555719.000000  5.557190e+05  555719.000000  555719.000000
# mean   277859.000000  4.178387e+17      69.392810   48842.628015
# std    160422.401459  1.309837e+18     156.745941   26855.283328
# min         0.000000  6.041621e+10       1.000000    1257.000000
# 25%    138929.500000  1.800429e+14       9.630000   26292.000000
# 50%    277859.000000  3.521417e+15      47.290000   48174.000000
# 75%    416788.500000  4.635331e+15      83.010000   72011.000000
# max    555718.000000  4.992346e+18   22768.110000   99921.000000
#
#                  lat           long      city_pop     unix_time  \
# count  555719.000000  555719.000000  5.557190e+05  5.557190e+05
# mean       38.543253     -90.231325  8.822189e+04  1.380679e+09
# std         5.061336      13.721780  3.003909e+05  5.201104e+06
# min        20.027100    -165.672300  2.300000e+01  1.371817e+09
# ...

# %%
# Check for missing values
print(train_data.isnull().sum())
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
# Explore the distribution of the target variable
print(train_data['is_fraud'].value_counts())
# Out:
# is_fraud
# 0    553574
# 1      2145
# Name: count, dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
# Feature Engineering and Preprocessing
# For simplicity, we'll drop 'trans_date_trans_time', 'first', 'last', 'street', 'city', 'state', 'job', 'dob', 'trans_num' as they might not be relevant for fraud detection
train_data.drop(['trans_date_trans_time', 'first', 'last', 'street', 'city', 'state', 'job', 'dob', 'trans_num','Unnamed: 0'], axis=1, inplace=True)
test_data.drop(['trans_date_trans_time', 'first', 'last', 'street', 'city', 'state', 'job', 'dob', 'trans_num','Unnamed: 0'], axis=1, inplace=True)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   cc_num      555719 non-null  int64
#  1   merchant    555719 non-null  object
#  2   category    555719 non-null  object
#  3   amt         555719 non-null  float64
#  4   gender      555719 non-null  object
#  5   zip         555719 non-null  int64
#  6   lat         555719 non-null  float64
#  7   long        555719 non-null  float64
#  8   city_pop    555719 non-null  int64
#  9   unix_time   555719 non-null  int64
#  10  merch_lat   555719 non-null  float64
#  11  merch_long  555719 non-null  float64
#  12  is_fraud    555719 non-null  int64
# dtypes: float64(5), int64(5), object(3)
# memory usage: 55.1+ MB

# %%
train_data.head()
# Out:
#              cc_num                              merchant        category  \
# 0  2291163933867244                 fraud_Kirlin and Sons   personal_care
# 1  3573030041201292                  fraud_Sporer-Keebler   personal_care
# 2  3598215285024754  fraud_Swaniawski, Nitzsche and Welch  health_fitness
# 3  3591919803438423                     fraud_Haley Group        misc_pos
# 4  3526826139003047                 fraud_Johnston-Casper          travel
#
#      amt gender    zip      lat      long  city_pop   unix_time  merch_lat  \
# 0   2.86      M  29209  33.9659  -80.9355    333497  1371816865  33.986391
# 1  29.84      F  84002  40.3207 -110.4360       302  1371816873  39.450498
# 2  41.28      F  11710  40.6729  -73.5365     34496  1371816893  40.495810
# 3  60.05      M  32780  28.5697  -80.8191     54767  1371816915  28.812398
# 4   3.19      M  49632  44.2529  -85.0170      1126  1371816917  44.959148
#
#    merch_long  is_fraud
# 0  -81.200714         0
# ...

# %%
# Separate features and target variable
X_train = train_data.drop('is_fraud', axis=1)
y_train = train_data['is_fraud']
X_test = test_data.drop('is_fraud', axis=1)
y_test = test_data['is_fraud']

# %%
# Identify categorical and numerical columns
categorical_features = ['merchant', 'category', 'gender']
numerical_features = X_train.select_dtypes(include=['int64', 'float64']).columns.tolist()
numerical_features = [col for col in numerical_features if col not in ['is_fraud']]

# %%
# Preprocessing for numerical data
numerical_transformer = StandardScaler()

# %%
# Preprocessing for categorical data
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

# %%
# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# %%
# Define models
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier()
}

# %%
# Create and evaluate a pipeline for each model
for name, model in models.items():
    clf = Pipeline(steps=[('preprocessor', preprocessor),
                          ('classifier', model)])

    print(f"Training {name}...")
    clf.fit(X_train, y_train)

    # Make predictions
    y_pred = clf.predict(X_test)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred)

    print(f"\n{name} Metrics:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-score: {f1:.4f}")
    print(f"ROC AUC: {roc_auc:.4f}")
# Out:
# Training Logistic Regression...
#
# Logistic Regression Metrics:
# Accuracy: 0.9937
# Precision: 0.0342
# Recall: 0.0029
# F1-score: 0.0054
# ROC AUC: 0.5012
# Training Decision Tree...
#
# Decision Tree Metrics:
# Accuracy: 0.9948
# Precision: 0.5628
# Recall: 0.4925
# F1-score: 0.5253
# ROC AUC: 0.7452
# Training Random Forest...
#
# Random Forest Metrics:
# Accuracy: 0.9953
# Precision: 0.9197
# Recall: 0.2013
# F1-score: 0.3303
# ROC AUC: 0.6006

# %% [markdown]
# ## Detailed Description of Model Performance
#
# ### Logistic Regression:
# - **Accuracy**: 0.9937 - The model correctly classified 99.37% of the transactions.
# - **Precision**: 0.0342 - Of all the transactions predicted as fraud, only 3.42% were actually fraud.
# - **Recall**: 0.0029 - Of all the actual fraud transactions, the model correctly identified only 0.29%.
# - **F1-score**: 0.0054 - This is a harmonic mean of precision and recall.
# - **ROC AUC**: 0.5012 - This indicates that the model has no discrimination capability (similar to random guessing).
#
# ### Decision Tree:
# - **Accuracy**: 0.9948 - The model correctly classified 99.48% of the transactions.
# - **Precision**: 0.5628 - Of all the transactions predicted as fraud, 56.28% were actually fraud.
# - **Recall**: 0.4925 - Of all the actual fraud transactions, the model correctly identified 49.25%.
# - **F1-score**: 0.5253 - This is a harmonic mean of precision and recall.
# - **ROC AUC**: 0.7452 - This indicates that the model has good discrimination capability.
#
# ### Random Forest:
# - **Accuracy**: 0.9953 - The model correctly classified 99.53% of the transactions.
# - **Precision**: 0.9197 - Of all the transactions predicted as fraud, 91.97% were actually fraud.
# - **Recall**: 0.2013 - Of all the actual fraud transactions, the model correctly identified 20.13%.
# - **F1-score**: 0.3303 - This is a harmonic mean of precision and recall.
# - **ROC AUC**: 0.6006 - This indicates that the model has moderate discrimination capability.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_curve, auc, precision_recall_curve
import numpy as np
import seaborn as sns

# Function to plot confusion matrix
def plot_conf_matrix(y_test, y_pred, ax, title):
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Legitimate', 'Fraud'], yticklabels=['Legitimate', 'Fraud'], ax=ax)
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    ax.set_title(title)

# Function to plot ROC curve
def plot_roc_curve(model, X_test, y_test, ax, title):
    y_score = model.predict_proba(X_test)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)

    ax.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    ax.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title(title)
    ax.legend(loc='lower right')

# Function to plot Precision-Recall curve
def plot_pr_curve(model, X_test, y_test, ax, title):
    y_score = model.predict_proba(X_test)[:, 1]
    precision, recall, _ = precision_recall_curve(y_test, y_score)

    ax.plot(recall, precision, color='b', lw=2)
    ax.set_xlabel('Recall')
    ax.set_ylabel('Precision')
    ax.set_title(title)

# Fit and evaluate models
for name, model in models.items():
    clf = Pipeline(steps=[('preprocessor', preprocessor), ('classifier', model)])
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)

    # Create subplots
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    # Plot confusion matrix
    plot_conf_matrix(y_test, y_pred, axes[0], f'{name} Confusion Matrix')

    # Plot ROC curve
    plot_roc_curve(clf, X_test, y_test, axes[1], f'{name} ROC Curve')

    # Plot Precision-Recall curve
    plot_pr_curve(clf, X_test, y_test, axes[2], f'{name} Precision-Recall Curve')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Explanation of the Visualization Functions
#
# ### Confusion Matrix:
# - The `plot_conf_matrix` function creates a heatmap to visualize the confusion matrix.
# - `sns.heatmap` from the seaborn library is used to plot the matrix.
# - The x-axis represents the predicted labels, while the y-axis represents the true labels.
#
# ### ROC Curve:
# - The `plot_roc_curve` function plots the ROC curve and calculates the area under the curve (AUC).
# - The false positive rate (FPR) is plotted on the x-axis, and the true positive rate (TPR) is plotted on the y-axis.
# - A diagonal line represents random guessing.
#
# ### Precision-Recall Curve:
# - The `plot_pr_curve` function plots the precision-recall curve.
# - Precision is plotted on the y-axis, and recall is plotted on the x-axis.
# - This curve is useful for evaluating the performance of classifiers, especially on imbalanced datasets.

# %% [markdown]
# ### Analysis:
#
# - **Logistic Regression**:
#   - **Accuracy**: 0.9937
#   - **Precision**: 0.0342
#   - **Recall**: 0.0029
#   - **F1-score**: 0.0054
#   - **ROC AUC**: 0.5012
#
# - **Decision Tree**:
#   - **Accuracy**: 0.9948
#   - **Precision**: 0.5628
#   - **Recall**: 0.4925
#   - **F1-score**: 0.5253
#   - **ROC AUC**: 0.7452
#
# - **Random Forest**:
#   - **Accuracy**: 0.9953
#   - **Precision**: 0.9197
#   - **Recall**: 0.2013
#   - **F1-score**: 0.3303
#   - **ROC AUC**: 0.6006
#
# #### Conclusion:
# Based on these metrics, the **Decision Tree** model appears to be the best choice for this project because it offers a good balance between precision and recall, as indicated by its F1-score and ROC AUC. While Random Forest has a very high precision, its recall is significantly lower, meaning it misses a larger number of actual fraud cases compared to the Decision Tree.
#
# Thus, for a practical fraud detection system where both capturing fraud cases and minimizing false positives are important, the Decision Tree model is the recommended choice.
